# %%
import config

# %%
config.prompt
# Out:
# '8 + 18 ='

# %%
directory = config.prompt + '/2022-11-30 20:00:09.514890'

# %%
def get_model(directory):
    import torch
    model = torch.load(directory)
    return model

# %%
def get_mean_hidden_state(model, hidden_number, token_number):
    return model[2][hidden_number].mean(dim=0).cpu().numpy()[token_number]

# %%
def compare_hidden_states(a, b):
    if(a.shape != b.shape):
        print("hidden state size not equal")
        return NULL
    diff = b - a
    return diff
def Average(lst):
    return sum(lst) / len(lst)

# %%
def plot_array(array,prompt, title):
    import pandas as pd
    import numpy as np
    import seaborn as sns
    import matplotlib.pyplot as plt

    np.random.seed(0)
    sns.set()
    # uniform_data = np.random.rand(10, 12)
    ax = sns.heatmap(array, vmin = 0, vmax = 1)
    plt.xlabel('hidden States')
    plt.ylabel(prompt)
    plt.title(title)
    plt.show()

# %%
def plot_diff_array(prompt, token_changed):
    base_model_directory = directory + '/' + 'base_model.pt'
    model_directory = directory + '/best_model' + str(token_changed) + '.pt'
    hidden_diff = []
    
    base_model = get_model(base_model_directory)
    model = get_model(model_directory)
    for j in range(4):
        temp = []
        for i in range(49):
            base_state = get_mean_hidden_state(base_model, i,j)
            state = get_mean_hidden_state(model, i, j)
            diff = compare_hidden_states(base_state, state)
            mean_diff = Average(diff)
            # print(mean_diff)
            temp.append(mean_diff)
        hidden_diff.append(temp)
    plot_array(hidden_diff,prompt,
               "Comparision of original model and model with " + str(token_changed) +  "th token restored" )
    # return hidden_diff

# %%
def diff_list(a, b):
    diff = []
    for i in range(len(a)):
        temp = []
        for j in range(len(a[0])):
            temp.append(b[i][j] - a[i][j])
        diff.append(temp)
    plot_array(diff, config.prompt, "")
    return diff

# %%
plot_diff_array(config.prompt, 0)

# %%
plot_diff_array(config.prompt, 1)

# %%
plot_diff_array(config.prompt, 2)

# %%
plot_diff_array(config.prompt, 3)

# %%
plot_diff_array(config.prompt, 4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [17], in <module>
# ----> 1 plot_diff_array(config.prompt, 4)
#
# Input In [11], in plot_diff_array(prompt, token_changed)
#       4 hidden_diff = []
#       6 base_model = get_model(base_model_directory)
# ----> 7 model = get_model(model_directory)
#       8 for j in range(4):
#       9     temp = []
#
# Input In [4], in get_model(directory)
#       1 def get_model(directory):
#       2     import torch
# ----> 3     model = torch.load(directory)
#       4     return model
#
# File ~/.local/lib/python3.8/site-packages/torch/serialization.py:771, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     768 if 'encoding' not in pickle_load_args.keys():
#     769     pickle_load_args['encoding'] = 'utf-8'
# --> 771 with _open_file_like(f, 'rb') as opened_file:
#     772     if _is_zipfile(opened_file):
#     773         # The zipfile reader is going to advance the current file position.
#     774         # If we want to actually tail call to torch.jit.load, we need to
#     775         # reset back to the original position.
#     776         orig_position = opened_file.tell()
#
# File ~/.local/lib/python3.8/site-packages/torch/serialization.py:270, in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# File ~/.local/lib/python3.8/site-packages/torch/serialization.py:251, in _open_file.__init__(self, name, mode)
#     250 def __init__(self, name, mode):
# --> 251     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '8 + 18 =/2022-11-30 20:00:09.514890/best_model4.pt'

# %%
plot_diff_array(config.prompt, 5)

# %%
plot_diff_array(config.prompt, 15)

# %%
plot_diff_array(config.prompt, 7)

# %%
plot_diff_array(config.prompt, 8)

# %%
plot_array(hidden_diff, "Comparision of base model and model with 0th token restored")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 plot_array(hidden_diff, "Comparision of base model and model with 0th token restored")
#
# NameError: name 'hidden_diff' is not defined

# %%
def plot_mean_lastHiddenState(number, directory):
    import torch
    model = torch.load(directory + '/best_model' + number + '.pt')
    mean_hidden_state = model[2][-1].mean(dim=0).cpu().numpy()
    import pandas as pd
    import numpy as np
    import seaborn as sns
    import matplotlib.pyplot as plt

    np.random.seed(0)
    sns.set()
    # uniform_data = np.random.rand(10, 12)
    ax = sns.heatmap(mean_hidden_state, vmin=0, vmax=1)
    plt.show()

# %%
model = get_model('0', 'Seven plus two is equal to')

# %%
base_model = torch.load("Seven plus two is equal to/base_model.pt")

# %%
len(base_model[2])
# Out:
# 49

# %%
hidden0 = get_mean_hidden_state(model, 0
# Out:
# 49

# %% [markdown]
# There are 49 hidden states in the model, each hidden state is of size batch_size, sequence_length, length

# %%
hidden_state = model[2][1]

# %%
hidden_state.shape
# Out:
# torch.Size([2, 6, 1600])

# %%
hidden_state.mean(dim=0).mean(dim=0).mean(dim=0)
# Out:
# tensor(-0.0167, device='cuda:0')

# %%
model[2][1].shape
# Out:
# torch.Size([2, 6, 1600])

# %%
column = model[2][0].mean(dim = 0)[0].cpu().numpy()

# %%
import seaborn as sns
fig, ax = plt.subplots()
sns.heatmap([column])

# %%
plot_mean_lastHiddenState('0', 'Seven plus two is equal to')

# %%
plot_mean_lastHiddenState('1', 'Seven plus two is equal to')

# %%
import torch
model = torch.load('Seven plus two is equal to/best_model0.pt')

# %%
# model = model.to_tuple()

# %%
type(model)
# Out:
# transformers.modeling_outputs.CausalLMOutputWithCrossAttentions

# %%
mean_hidden_state = model[2][-1].mean(dim=0).cpu().numpy()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
sns.set()
# uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(mean_hidden_state, vmin=0, vmax=1)
plt.show()
